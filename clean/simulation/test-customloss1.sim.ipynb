# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.3):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale=1):
        scale_wrong = max(sum(output[0])/len(output[0]), 10) * scale
        scale_true = scale_wrong * 3
        tempLabels = torch.ones_like(output)* -1 * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 400, bias=False)
        self.bn1 = nn.BatchNorm1d(400)
        self.htanh1 = nn.Hardtanh()
        self.fc3 = BinarizeLinear(400, 200, bias=False)
        self.bn3 = nn.BatchNorm1d(200)
        self.htanh3 = nn.Hardtanh()
        self.fc4 = BinarizeLinear(200, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-customloss1.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[-11.,  -9.,  -1., -16.,  -9.,  21., -16., -13.,  -8.,  -9.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9624739140000003 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6459416759999996 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1317966119999996 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 5 spikes of frequency 4.175
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 14 spikes of frequency 2.3461538461538463
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 34., -12., -14.,  -5., -18., -12.,  -8., -17.,  -6., -12.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.925857968999992 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5443919240000099 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.09248402999999428 seconds
# creating stimulation
# starting to record
# for 0 found 15 spikes of frequency 2.314285714285714
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1., -13., -12.,  -8.,  21.,  -7.,  -3.,  -6., -12., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8314424659999986 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5298335290000011 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.06371366599998396 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 14 spikes of frequency 2.2615384615384615
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-13.,  31.,  -9., -10., -11., -13., -15., -17., -10., -10.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8494685840000216 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5064217679999956 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.12297845599999846 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 14 spikes of frequency 2.176923076923077
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-11., -10.,  -7.,  -8.,  -9.,  -8., -11.,  -8., -10.,  34.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9590877140000202 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.610766754999986 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1073847050000154 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 15 spikes of frequency 2.335714285714286
# simulation result:
# ANN result: tensor([[ -7., -14.,  24.,  -5., -14., -24.,  -3., -13., -10., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8836724139999887 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6237655140000129 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.13803629800003137 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 14 spikes of frequency 2.2153846153846155
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -6., -14.,  -2.,  34., -16., -12., -16., -21.,  -4., -20.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.779799378000007 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.532140341999991 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.06500828700001193 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 14 spikes of frequency 2.223076923076923
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1., -14.,  -6.,  -2., -16., -11.,  21., -14.,  -6.,  -5.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8300433050000038 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5469317739999724 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.05956961300000785 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 14 spikes of frequency 2.169230769230769
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -4.,  -1., -14., -24.,  -8., -12., -10.,  24., -18., -10.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9488901240000018 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.617923530999974 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.16520931799999516 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 15 spikes of frequency 2.357142857142857
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -6., -13.,  -6.,  -2., -26., -17., -13.,  -9.,  21.,  -6.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8707120059999625 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5809049199999663 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.12746089400002347 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 12 spikes of frequency 2.190909090909091
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
