# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn

class customLoss(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_wrong=20, scale_true=100):
        tempLabels = torch.ones_like(output)*-1*scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 400, bias=False)
        self.bn1 = nn.BatchNorm1d(400)
        self.htanh1 = nn.Hardtanh()
        self.drop=nn.Dropout(0.5)
        self.fc3 = BinarizeLinear(400, 200, bias=False)
        self.bn3 = nn.BatchNorm1d(200)
        self.htanh3 = nn.Hardtanh()
        self.fc4 = BinarizeLinear(200, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        #x = self.bn1(x)
        #print("b4", x)
        x = self.htanh1(x)
        #print("after", x)
        #exit()
        x = self.drop(x)
        x = self.fc3(x)
        #x = self.bn3(x)
        x = self.htanh3(x)
        x = self.fc4(x)
        #x = self.logsoftmax(x)
        return x

    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x



model = Net()
model.load_state_dict(torch.load("trained_models/testDEBUG2.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -7.,  -7.,   3., -25., -19.,  23., -37., -33., -15., -19.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9192913950000001 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6146803699999994 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.0814014959999998 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 4 spikes of frequency 2.5333333333333337
# for 2 found 8 spikes of frequency 2.614285714285714
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 12 spikes of frequency 2.3545454545454545
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 86., -12., -30., -12., -28., -16., -12., -10., -36., -42.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.873021499999993 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5780428599999965 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.0729974200000072 seconds
# creating stimulation
# starting to record
# for 0 found 15 spikes of frequency 2.207142857142857
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-18., -34., -28., -36.,   8., -24., -24.,   0.,  -6., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.0155753610000033 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6133539389999783 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.07199375000001851 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 12 spikes of frequency 2.2818181818181817
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-42.,  70., -42., -40.,  -4., -40.,  22., -36., -12., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.7887157669999851 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5002885600000013 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.08297606300001803 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 14 spikes of frequency 2.2076923076923074
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 11 spikes of frequency 2.48
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-34., -38., -28.,  -2.,   8., -48., -42.,   2., -14.,  20.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9674523809999869 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6710661989999949 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.05055606400000556 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 9 spikes of frequency 2.1625
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 10 spikes of frequency 3.0444444444444443
# for 8 found 0 spikes
# for 9 found 14 spikes of frequency 2.184615384615385
# simulation result:
# ANN result: tensor([[ 11., -43.,  11.,  -5., -17., -21., -31., -13., -29., -29.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8248578530000259 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6615471279999952 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.049731796000003214 seconds
# creating stimulation
# starting to record
# for 0 found 4 spikes of frequency 2.266666666666667
# for 1 found 0 spikes
# for 2 found 11 spikes of frequency 2.2700000000000005
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -4.,  -8., -18.,  34., -44.,  18., -32., -34., -16., -20.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8076876540000058 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6360824719999982 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.09803255200000649 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 15 spikes of frequency 2.25
# for 4 found 0 spikes
# for 5 found 14 spikes of frequency 2.2384615384615385
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-20., -12., -20., -48., -38., -24.,  46., -14., -46., -24.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8701689320000128 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5138118509999572 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1299096719999966 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 13 spikes of frequency 2.191666666666667
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -6., -32., -20.,  -4., -34., -36., -22.,  50., -40., -18.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9562397650000776 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5970188080000298 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.07124772300005588 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 15 spikes of frequency 2.164285714285714
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-23., -43., -19.,   1., -29., -33., -35.,   3.,  37., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8917183660000774 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5765899399999626 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.04896395699995537 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 11 spikes of frequency 2.170000000000001
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
