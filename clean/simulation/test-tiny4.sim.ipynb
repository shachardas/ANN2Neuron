# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.3):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale=1):
        scale_wrong = max(sum(output[0])/len(output[0]), 5) * scale
        scale_true = scale_wrong * 3
        tempLabels = torch.ones_like(output)* -1 * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 50, bias=False)
        self.fc4 = BinarizeLinear(50, 10, bias=False)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-tiny4.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -7.,   6.,   0., -10.,   0.,  12.,  -9.,  -6.,  -7.,  -9.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3660733269999996 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.09449951300000059 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 5 spikes of frequency 2.4250000000000003
# for 2 found 1 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 8 spikes of frequency 2.385714285714286
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 14.,  -3.,  -4.,  -8., -11.,  -5.,  -9.,  -5.,  -3.,  -1.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3376613189999915 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.11891777499999989 seconds
# creating stimulation
# starting to record
# for 0 found 8 spikes of frequency 2.3999999999999995
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-3.,  0.,  0., -4., 14., -5., -9., -6., -7.,  2.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.40717538199999126 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.05130632199998786 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 7 spikes of frequency 2.3
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 3 spikes of frequency 3.8500000000000005
# simulation result:
# ANN result: tensor([[-8., 17.,  2., -4., -3., -8., -3., -5., -3., -4.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3255356820000088 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.11614735699998846 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 8 spikes of frequency 2.885714285714286
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1.,   7.,  -7., -11.,  -5.,  -7.,  -6.,  -9.,  -2.,  17.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3657726759999491 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.044655643999988115 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 5 spikes of frequency 2.6999999999999997
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 8 spikes of frequency 2.3999999999999995
# simulation result:
# ANN result: tensor([[-6., -3.,  2.,  2., -9., -3.,  0., -8., -2.,  2.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3107348609999576 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.05298788099997864 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 5 spikes of frequency 3.0250000000000004
# for 3 found 1 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 4 spikes of frequency 3.966666666666667
# simulation result:
# ANN result: tensor([[-7., -3., -4., 13., -9., -5., -7., -6., -7., -5.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3213662389999854 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.05981522999996969 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 8 spikes of frequency 2.542857142857143
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -3.,  -1., -11.,   2.,  -5.,  -6.,  11.,  -6.,  -8.,  -3.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.30688383099993644 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.04872537699998247 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 2 spikes of frequency 3.0000000000000018
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 7 spikes of frequency 2.6833333333333336
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1.,   2., -11., -10.,  -6.,  -6., -10.,   5.,  -6.,   8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.2770220279999194 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.023303714999997283 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 6 spikes of frequency 2.48
# for 8 found 0 spikes
# for 9 found 7 spikes of frequency 2.6666666666666665
# simulation result:
# ANN result: tensor([[-11.,   1.,  -7.,  -1.,  -5.,  -3.,  -5.,  -8.,   3.,   1.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3786423400000558 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.04974829800005409 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 5 spikes of frequency 2.5749999999999997
# for 9 found 5 spikes of frequency 3.6500000000000004
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
