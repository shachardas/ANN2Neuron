# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn

class customLoss(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_wrong=20, scale_true=100):
        tempLabels = torch.ones_like(output)*-1*scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 400, bias=False)
        self.bn1 = nn.BatchNorm1d(400)
        self.htanh1 = nn.Hardtanh()
        self.fc3 = BinarizeLinear(400, 200, bias=False)
        self.bn3 = nn.BatchNorm1d(200)
        self.htanh3 = nn.Hardtanh()
        self.fc4 = BinarizeLinear(200, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-small-and-simple.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[-33.,  33., -25., -13.,  11.,  47., -39., -19., -41., -43.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9214597449999928 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6415001160000884 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1813562820000243 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 15 spikes of frequency 2.1928571428571426
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 12 spikes of frequency 2.4090909090909096
# for 5 found 16 spikes of frequency 2.18
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 74.,  10., -46.,  12.,   0., -26., -26.,  -8., -34., -12.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9401337350000176 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5692880949998198 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.13091625800007023 seconds
# creating stimulation
# starting to record
# for 0 found 17 spikes of frequency 2.18125
# for 1 found 5 spikes of frequency 2.7
# for 2 found 0 spikes
# for 3 found 9 spikes of frequency 2.25
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-11., -13., -41., -25.,  97., -41., -25.,  -7., -23., -37.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8019211739999719 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6340593700001591 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1058887539998068 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 17 spikes of frequency 2.2250000000000005
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-27.,  93., -49.,  -9., -29., -41.,  -3., -23., -41., -39.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9131539200000134 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6487388319999354 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.08192406600005597 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 17 spikes of frequency 2.1875
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -9.,   1., -45., -13.,   1., -25., -21.,   1., -33.,  89.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.204511679999996 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.655764445000159 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.15325388900009784 seconds
# creating stimulation
# starting to record
# for 0 found 1 spikes
# for 1 found 9 spikes of frequency 3.5375
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 15 spikes of frequency 2.4285714285714284
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 5 spikes of frequency 2.8499999999999996
# for 8 found 0 spikes
# for 9 found 17 spikes of frequency 2.21875
# simulation result:
# ANN result: tensor([[-11.,   1.,  67.,  27.,  13., -49., -41.,   5.,  -9., -33.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9029580870001155 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6665661760000603 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.06656829700000344 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 15 spikes of frequency 2.164285714285714
# for 3 found 12 spikes of frequency 2.2
# for 4 found 7 spikes of frequency 2.266666666666667
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -3.,   7., -17., 119., -11., -39.,   7.,  -7., -39., -15.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.976365479000151 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6159604669999226 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.08989763099998527 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 2 spikes of frequency 2.6000000000000014
# for 2 found 0 spikes
# for 3 found 17 spikes of frequency 2.1625000000000005
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-22., -14., -42.,  -4., -18., -54.,  94., -20., -12., -42.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9611801410001135 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6346554719998494 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.06566493400009676 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 17 spikes of frequency 2.2437500000000004
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[  1.,   1., -63.,  -1.,  15., -51., -21.,  83., -23., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.9531841670000176 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6267605279999771 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.031922147999921435 seconds
# creating stimulation
# starting to record
# for 0 found 2 spikes of frequency 7.500000000000002
# for 1 found 9 spikes of frequency 2.4250000000000003
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 7 spikes of frequency 2.1999999999999997
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 17 spikes of frequency 2.1937500000000005
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-30.,  12., -42.,   0.,  -8., -26.,  -4.,  10.,  56.,  -2.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 0.8313979489998928 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.5228120440001476 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.07964573099980043 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 12 spikes of frequency 2.1727272727272724
# for 2 found 0 spikes
# for 3 found 5 spikes of frequency 2.5250000000000004
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 6 spikes of frequency 3.0999999999999996
# for 8 found 15 spikes of frequency 2.2142857142857144
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
