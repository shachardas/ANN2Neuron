# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.3):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale=1):
        scale_wrong = max(sum(output[0])/len(output[0]), 5) * scale
        scale_true = scale_wrong * 5
        tempLabels = torch.ones_like(output)* -1 * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 50, bias=False)
        self.fc4 = BinarizeLinear(50, 10, bias=False)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-tiny2.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -8.,   6.,   1., -10.,  -3.,  18.,  -9.,  -3.,  -9., -20.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.28146679399999996 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.09894924500000002 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 8 spikes of frequency 2.7285714285714286
# for 2 found 1 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 8 spikes of frequency 2.2714285714285714
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[17., -7., -1., -8., -5., -2., -7.,  3., -5., -9.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.29346533800000074 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0723689510000014 seconds
# creating stimulation
# starting to record
# for 0 found 9 spikes of frequency 2.3125
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 3 spikes of frequency 3.000000000000001
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-9., -7., -2., -3., 14., -5., -6., -3., -8., -4.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3534061849999972 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.025839016000006154 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 8 spikes of frequency 2.3000000000000003
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-10.,  22.,  -8.,  -4.,  -4.,  -6.,  -6.,  -5.,  -7., -10.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.19695748699999172 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0040819139999968 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 8 spikes of frequency 2.3285714285714287
# for 2 found 0 spikes
# for 3 found 1 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -4.,   6.,  -6., -11.,   1., -10.,  -7.,  -5.,  -4.,  17.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.2296339530000182 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.04445659200001728 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 3 spikes of frequency 2.5
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 5 spikes of frequency 3.9000000000000004
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 8 spikes of frequency 2.2714285714285714
# simulation result:
# ANN result: tensor([[-10.,  -8.,  10.,  -6.,  -3.,  -5.,   0.,   0.,  -7.,  -1.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.1285878260000004 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.11050700600000596 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 8 spikes of frequency 2.8142857142857145
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-4., -6., -2., 17., -3.,  1., -5., -5., -3., -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.30622096400000487 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0662265989999753 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 9 spikes of frequency 2.3500000000000005
# for 4 found 0 spikes
# for 5 found 1 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1.,  -2.,  -2., -10.,   1.,  -4.,  16.,  -5.,  -6.,  -6.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.25858469199999945 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.06517022700001007 seconds
# creating stimulation
# starting to record

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
