# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn

class customLoss(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_wrong=20, scale_true=100):
        tempLabels = torch.ones_like(output)*-1*scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 400, bias=False)
        self.bn1 = nn.BatchNorm1d(400)
        self.htanh1 = nn.Hardtanh()
        self.fc3 = BinarizeLinear(400, 200, bias=False)
        self.bn3 = nn.BatchNorm1d(200)
        self.htanh3 = nn.Hardtanh()
        self.fc4 = BinarizeLinear(200, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-small-and-simple.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[-23.,   5.,  13., -19., -33.,  79., -37., -13., -25., -59.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.0857076410000008 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.7456907130000001 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.13474337700000039 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 15 spikes of frequency 2.2857142857142856
# for 2 found 14 spikes of frequency 2.307692307692308
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 17 spikes of frequency 2.2937499999999997
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 93.,  -7., -25., -25., -11.,  -5., -21.,   3., -35., -39.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.0148211089999997 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.648013401 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.09942682899999866 seconds
# creating stimulation
# starting to record
# for 0 found 17 spikes of frequency 2.18125
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 14 spikes of frequency 2.2538461538461543
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -9., -25., -27., -13., 101., -15., -41., -23.,   3., -19.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.0332724350000007 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6012079149999963 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.1115007530000014 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 17 spikes of frequency 2.1625000000000005
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-19.,  91., -27., -11., -29.,   1., -19.,  -7.,  -1., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.047755366000004 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6318626600000101 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.07977934500000572 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 17 spikes of frequency 2.20625
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-41., -31.,   3., -57.,  35., -31., -43., -23.,  17.,  45.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 800, 400, 10]
# creating 784 nodes
# creating 800 nodes
# connecting 784 neurons to 800 neurons
# this took 1.3382028739999896 seconds
# creating 400 nodes
# connecting 800 neurons to 400 neurons
# this took 0.6772576910000225 seconds
# creating 10 nodes
# connecting 400 neurons to 10 neurons
# this took 0.06731050499999469 seconds
# creating stimulation

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
