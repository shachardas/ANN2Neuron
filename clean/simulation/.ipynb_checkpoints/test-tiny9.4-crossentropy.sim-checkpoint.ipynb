# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_true=100, scale_wrong=-10):
        # scale_wrong = max(sum(output[0])/len(output[0]), 2) * scale
        # scale_true = scale_wrong * 10
        tempLabels = torch.ones_like(output) * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 50, bias=False)
        self.fc4 = BinarizeLinear(50, 10, bias=False)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-tiny9.4-crossentropy.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -2.,   8.,   2.,  -6.,   3.,  11.,  -4.,   0.,   2., -18.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.1564727829999999 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.005908334999999987 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 7 spikes of frequency 2.5333333333333337
# for 2 found 6 spikes of frequency 3.08
# for 3 found 0 spikes
# for 4 found 5 spikes of frequency 3.725
# for 5 found 8 spikes of frequency 2.3285714285714287
# for 6 found 0 spikes
# for 7 found 2 spikes of frequency 9.0
# for 8 found 7 spikes of frequency 2.8666666666666667
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 18.,  -9.,  -4., -15., -10.,   7.,   1.,   0.,  -1.,  -9.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.19292335400000127 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0009497600000010209 seconds
# creating stimulation
# starting to record
# for 0 found 9 spikes of frequency 2.3125
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 6 spikes of frequency 2.5000000000000004
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-12., -13.,  -1.,  -3.,  12.,  -6.,   0.,   2.,   4.,   2.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15828576400000038 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0010573310000001612 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 9 spikes of frequency 2.4875
# for 5 found 0 spikes
# for 6 found 2 spikes of frequency 5.699999999999999
# for 7 found 1 spikes
# for 8 found 4 spikes of frequency 2.5666666666666664
# for 9 found 4 spikes of frequency 2.866666666666667
# simulation result:
# ANN result: tensor([[-17.,  15.,   1.,  -3.,  -6.,   2., -12.,   7.,   5.,  -5.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.1583878340000009 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0010672510000002688 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 8 spikes of frequency 2.3428571428571425
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 3 spikes of frequency 3.8
# for 6 found 0 spikes
# for 7 found 7 spikes of frequency 2.6666666666666665
# for 8 found 6 spikes of frequency 2.9200000000000004
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-6.,  3., -4., -8.,  5., -6.,  3.,  4.,  0., 23.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15671376900000134 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0008743569999989376 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 5 spikes of frequency 2.925
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 8 spikes of frequency 2.7285714285714286
# for 5 found 0 spikes
# for 6 found 6 spikes of frequency 2.7
# for 7 found 6 spikes of frequency 2.68
# for 8 found 2 spikes of frequency 2.6000000000000014
# for 9 found 9 spikes of frequency 2.2875000000000005
# simulation result:
# ANN result: tensor([[-10., -13.,  14.,  -1.,  -6.,  -6.,  -4.,   0.,  -1.,  -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.1573643330000003 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0009022690000008993 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 8 spikes of frequency 2.2857142857142856
# for 3 found 2 spikes of frequency 4.9
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 0., -4.,  0., 18., -4.,  7., -9., -5.,  2., -9.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15877612300000088 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0009609929999996325 seconds
# creating stimulation
# starting to record
# for 0 found 2 spikes of frequency 3.1000000000000014
# for 1 found 0 spikes
# for 2 found 1 spikes
# for 3 found 9 spikes of frequency 2.3000000000000003
# for 4 found 0 spikes
# for 5 found 8 spikes of frequency 2.5
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -1.,  -5.,   6., -15.,   7.,   2.,  15.,  -7.,   2.,   0.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.16005030100000006 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0011969620000016334 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 6 spikes of frequency 2.56
# for 3 found 0 spikes
# for 4 found 7 spikes of frequency 2.5833333333333335
# for 5 found 1 spikes
# for 6 found 8 spikes of frequency 2.3285714285714283
# for 7 found 0 spikes
# for 8 found 6 spikes of frequency 2.96
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -4.,  -5., -13.,  -1.,   1.,  -4.,  -8.,  16.,  -5.,   7.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15901450899999858 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0021838069999979837 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 9 spikes of frequency 2.4375
# for 8 found 0 spikes
# for 9 found 8 spikes of frequency 2.3714285714285714
# simulation result:
# ANN result: tensor([[-10.,   5.,  -3.,  -8.,  -6.,   1.,  -5.,  -5.,  10.,   4.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.13086775000000017 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0009795540000006042 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 5 spikes of frequency 3.025
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 5 spikes of frequency 2.95
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 8 spikes of frequency 2.442857142857143
# for 9 found 5 spikes of frequency 3.3000000000000003
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
