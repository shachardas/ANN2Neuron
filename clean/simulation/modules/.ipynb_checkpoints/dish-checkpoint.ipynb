# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from dish import Dish
import math

dish = Dish()

node = dish.node()
node2 = dish.node()

dish.stimulateNode(node, lambda x : math.sin(0.1*x))
#dish.stimulateNode(node)
dish.connect(node, node2, 1)
dish.monitorNode(node2)

dish.record(3)
# Out:
# [{'type': 'spike_recorder',
#   'times': array([ 21.6,  25.6,  84.6,  88.6, 147.6, 151.6, 210.6, 214.6, 272.6,
#          276.5, 281. , 335.6, 339.5, 344. , 398.6, 402.6, 461.6, 465.6,
#          524.6, 528.6, 587.6, 591.6, 649.6, 653.5, 658. , 712.6, 716.5,
#          721. , 775.6, 779.6, 838.6, 842.6, 901.6, 905.6, 964.6, 968.6]),
#   'events': array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#          2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])}]

# %%
import nest
dish = Dish()

node = nest.Create("iaf_psc_alpha", 1, params={"C_m": 250.0,"tau_m": 10.0})
node2 = dish.node()

dish.stimulateNode(node, [1,10,20,30])
dish.connect(node, node2, 1)
dish.monitorNode(node2)

dish.record(3)
# Out:
# [{'type': 'spike_recorder',
#   'times': array([13.6, 20.2, 29.3, 39. ]),
#   'events': array([2, 2, 2, 2])}]

# %%
import nest
from dish import Dish
dish = Dish()

nodeP = dish.node()
nodeN = dish.node()
nodeR = dish.node()

dish.stimulateNode(nodeP, [1])
dish.connect(nodeP, nodeR, 10)

dish.stimulateNode(nodeP, [1])
dish.connect(nodeN, nodeR, -10)

#dish.connect(nodeR, nodeR, 1)
dish.monitorNode(nodeR)

dish.record(3)
# Out:
# [{'type': 'spike_recorder',
#   'times': array([ 13.6,  19.5,  25.1,  30.6,  36. ,  39.6,  43.3,  47.4,  51.9,
#           56.7,  61.7,  66.8,  72. ,  77.2,  82.4,  87.6,  92.8,  98. ,
#          103.2, 108.4, 113.6, 118.8, 124. , 129.2, 134.4, 139.6, 144.8,
#          150. , 155.2, 160.4, 165.6, 170.8, 176. , 181.2, 186.4, 191.6,
#          196.8, 202. , 207.2, 212.4, 217.6, 222.8, 228. , 233.2, 238.4,
#          243.6, 248.8, 254. , 259.2, 264.4, 269.6, 274.8, 280. , 285.2,
#          290.4, 295.6, 300.8, 306. , 311.2, 316.4, 321.6, 326.8, 332. ,
#          337.2, 342.4, 347.6, 352.8, 358. , 363.2, 368.4, 373.6, 378.8,
#          384. , 389.2, 394.4, 399.6, 404.8, 410. , 415.2, 420.4, 425.6,
#          430.8, 436. , 441.2, 446.4, 451.6, 456.8, 462. , 467.2, 472.4,
#          477.6, 482.8, 488. , 493.2, 498.4, 503.6, 508.8, 514. , 519.2,
#          524.4, 529.6, 534.8, 540. , 545.2, 550.4, 555.6, 560.8, 566. ,
#          571.2, 576.4, 581.6, 586.8, 592. , 597.2, 602.4, 607.6, 612.8,
#          618. , 623.2, 628.4, 633.6, 638.8, 644. , 649.2, 654.4, 659.6,
#          664.8, 670. , 675.2, 680.4, 685.6, 690.8, 696. , 701.2, 706.4,
#          711.6, 716.8, 722. , 727.2, 732.4, 737.6, 742.8, 748. , 753.2,
#          758.4, 763.6, 768.8, 774. , 779.2, 784.4, 789.6, 794.8, 800. ,
#          805.2, 810.4, 815.6, 820.8, 826. , 831.2, 836.4, 841.6, 846.8,
#          852. , 857.2, 862.4, 867.6, 872.8, 878. , 883.2, 888.4, 893.6,
#          898.8, 904. , 909.2, 914.4, 919.6, 924.8, 930. , 935.2, 940.4,
#          945.6, 950.8, 956. , 961.2, 966.4, 971.6, 976.8, 982. , 987.2,
#          992.4, 997.6]),
#   'events': array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#          3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])}]
