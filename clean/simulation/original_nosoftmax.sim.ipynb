# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_true=10, scale_wrong=-10):
        # scale_wrong = max(sum(output[0])/len(output[0]), 2) * scale
        # scale_true = scale_wrong * 10
        tempOut = torch.where(output>0,output*scale_wrong,torch.zeros_like(output))
        tempLabels = torch.ones_like(output) * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            #tempLabels[i,j] = scale_true 
            tempLabels[i,j] = torch.max(torch.abs(torch.mean(output[i])), torch.abs(output[i,j]))*scale_true
        #output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(tempOut, tempLabels) \
            + (1-self.p) * self.cost(output,labels)


criterion = nn.CrossEntropyLoss()
#criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.max(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.min(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

"""def Binarize(tensor, include_zero = True):
        if include_zero:
            return ((tensor+0.5).sign()+(tensor-0.5).sign())/2
        else:
            return tensor.sign()"""

class PositiveBinarizeLinear(nn.Linear):

        def __init__(self, *kargs, **kwargs):
            super(PositiveBinarizeLinear, self).__init__(*kargs, **kwargs)
    
        def forward(self, input):
            
            if input.size(1) != 784:
                input.data=Binarize(input.data)
                input.data = input.data.add(1).div(2)
            #zero = torch.zeros_like(input.data)
            #input.data = torch.where(input.data > 0, input.data, zero)
            input.data=Binarize(input.data)
            if not hasattr(self.weight,'org'):
                self.weight.org=self.weight.data.clone()
            self.weight.data=Binarize(self.weight.org)
            out = nn.functional.linear(input, self.weight)
            if not self.bias is None:
                self.bias.org=self.bias.data.clone()
                out += self.bias.view(1, -1).expand_as(out)

            return out

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

# simplified batchnorm with no mean normalization or learnable parameters
class myBatchNorm1d(nn.BatchNorm1d):

    def __init__(self, *kargs, **kwargs):
        super(myBatchNorm1d, self).__init__(*kargs, **kwargs)
        self.eps = 1e-5

    def forward(self, input):

        top = input
        bottom = torch.sqrt(torch.var(input) + self.eps)

        out = top/bottom

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.infl_ratio=3
        self.fc1 = BinarizeLinear(784, 1024*self.infl_ratio, bias=False)
        self.htanh1 = nn.Hardtanh()
        self.bn1 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc2 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh2 = nn.Hardtanh()
        self.bn2 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc3 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh3 = nn.Hardtanh()
        self.bn3 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc4 = nn.Linear(1024*self.infl_ratio, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()
        self.drop=nn.Dropout(0.5)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.htanh1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.htanh2(x)
        x = self.fc3(x) 
        x = self.drop(x)
        x = self.bn3(x)
        x = self.htanh3(x)
        x = self.fc4(x)
        return x#self.logsoftmax(x)


model = Net()
model.load_state_dict(torch.load("trained_models/original_nosoftmax.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ 6.6877, 10.6957,  8.9373, 12.0191,  8.1579, 19.9771,  7.4187,  5.1761,
#          11.2658,  8.9431]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# /home/shachar/nestDocker/ANN2Neuron/clean/simulation/modules/dishNetwork.py:19: UserWarning:To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# this took 7.36587976 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 44.454483859 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 41.480386504 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.183802067000002 seconds
# creating stimulation
# starting to record
# for 0 found 2 spikes of frequency 4.200000000000003
# for 1 found 27 spikes of frequency 2.269230769230769
# for 2 found 27 spikes of frequency 2.353846153846154
# for 3 found 28 spikes of frequency 2.2333333333333334
# for 4 found 27 spikes of frequency 2.3076923076923075
# for 5 found 28 spikes of frequency 2.144444444444445
# for 6 found 20 spikes of frequency 3.0263157894736845
# for 7 found 25 spikes of frequency 2.3125
# for 8 found 27 spikes of frequency 2.184615384615385
# for 9 found 24 spikes of frequency 2.4695652173913047
# simulation result:
# ANN result: tensor([[ 14.8754, -23.1498,  -3.8343, -10.4991, -14.5214,   0.3966,   2.3917,
#          -17.6094,  -0.8688,  -3.8424]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.789920921999993 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 45.49148187999998 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 35.10213595700003 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.21459826299997076 seconds
# creating stimulation
# starting to record
# for 0 found 27 spikes of frequency 2.1384615384615384
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 26 spikes of frequency 2.26
# for 6 found 20 spikes of frequency 2.4631578947368418
# for 7 found 0 spikes
# for 8 found 19 spikes of frequency 3.011111111111111
# for 9 found 6 spikes of frequency 10.0
# simulation result:
# ANN result: tensor([[ 9.8832,  8.3147,  8.7119,  6.3797, 18.7586, 12.6708, 10.8868, 10.2089,
#           8.3942, 12.4271]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.360877479999999 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 35.305608045999975 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 36.71245812800004 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.15833050899999535 seconds
# creating stimulation
# starting to record
# for 0 found 26 spikes of frequency 2.364
# for 1 found 22 spikes of frequency 2.661904761904762
# for 2 found 26 spikes of frequency 2.2920000000000003
# for 3 found 26 spikes of frequency 2.4
# for 4 found 28 spikes of frequency 2.1370370370370373
# for 5 found 28 spikes of frequency 2.1481481481481484
# for 6 found 27 spikes of frequency 2.3653846153846154
# for 7 found 28 spikes of frequency 2.2185185185185183
# for 8 found 26 spikes of frequency 2.228
# for 9 found 28 spikes of frequency 2.1666666666666665
# simulation result:
# ANN result: tensor([[-20.8165,  26.7447,   6.7766,   4.6157,   0.9374,  -9.2072,  -9.3846,
#           -2.5503,   4.7234,  -2.1489]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.7123666929999786 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.208832862999998 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.10726355899999 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1459325840000929 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 27 spikes of frequency 2.1346153846153846
# for 2 found 26 spikes of frequency 2.264
# for 3 found 26 spikes of frequency 2.2600000000000002
# for 4 found 21 spikes of frequency 2.7750000000000004
# for 5 found 7 spikes of frequency 9.216666666666667
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 25 spikes of frequency 2.2916666666666665
# for 9 found 19 spikes of frequency 2.7500000000000004
# simulation result:
# ANN result: tensor([[ 0.9165,  1.2543, -2.9372,  7.2861,  8.6467, 11.5478,  1.8218,  8.6684,
#          10.1869, 28.3711]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.093385070000068 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.191503271999977 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.14964648700004 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12745035199998256 seconds
# creating stimulation
# starting to record
# for 0 found 9 spikes of frequency 2.6624999999999996
# for 1 found 10 spikes of frequency 2.333333333333334
# for 2 found 1 spikes
# for 3 found 23 spikes of frequency 2.4136363636363636
# for 4 found 25 spikes of frequency 2.3000000000000003
# for 5 found 26 spikes of frequency 2.1879999999999997
# for 6 found 10 spikes of frequency 2.4111111111111114
# for 7 found 27 spikes of frequency 2.2
# for 8 found 25 spikes of frequency 2.204166666666667
# for 9 found 28 spikes of frequency 2.2333333333333334
# simulation result:
# ANN result: tensor([[ 6.2935,  5.7061, 26.3460,  8.2613, 10.6114, -2.6282, -1.8811,  8.9291,
#           3.1927, -1.0439]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.417367108000008 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.54063664900002 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.904230109000082 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.130411233000018 seconds
# creating stimulation
# starting to record
# for 0 found 22 spikes of frequency 2.509523809523809
# for 1 found 21 spikes of frequency 2.505
# for 2 found 28 spikes of frequency 2.1481481481481484
# for 3 found 26 spikes of frequency 2.3280000000000003
# for 4 found 26 spikes of frequency 2.2039999999999997
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 24 spikes of frequency 2.1956521739130435
# for 8 found 19 spikes of frequency 3.0777777777777775
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-17.5688, -11.8967,  -5.7589,  -0.1375, -20.1264, -11.8847, -20.6859,
#          -11.5735,  -8.9080, -10.9021]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.071595654000021 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.36835127100005 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.799272722999945 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1227837000000136 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 1 spikes
# for 2 found 5 spikes of frequency 14.499999999999998
# for 3 found 26 spikes of frequency 2.2640000000000002
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[10.7665,  8.1131,  9.9196,  8.7314, 12.1948, 13.0521, 18.1971,  0.0988,
#           9.3778,  8.2295]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.9978760459999876 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.434205851 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.36219422399995 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12905247700018663 seconds
# creating stimulation
# starting to record
# for 0 found 27 spikes of frequency 2.3038461538461537
# for 1 found 22 spikes of frequency 2.795238095238095
# for 2 found 27 spikes of frequency 2.246153846153846
# for 3 found 27 spikes of frequency 2.253846153846154
# for 4 found 29 spikes of frequency 2.1821428571428574
# for 5 found 29 spikes of frequency 2.2
# for 6 found 29 spikes of frequency 2.192857142857143
# for 7 found 6 spikes of frequency 12.000000000000002
# for 8 found 27 spikes of frequency 2.2538461538461543
# for 9 found 27 spikes of frequency 2.3499999999999996
# simulation result:
# ANN result: tensor([[ -6.4830, -14.3022, -12.2781,  -9.3123,  -8.1464,  -8.3992, -14.5201,
#            5.0238,  -5.2861,  -1.6244]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.596716383000057 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.355760735000104 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.488652895000087 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.15913605000014286 seconds
# creating stimulation
# starting to record
# for 0 found 1 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 2 spikes of frequency 2.3000000000000007
# for 6 found 0 spikes
# for 7 found 27 spikes of frequency 2.1423076923076922
# for 8 found 1 spikes
# for 9 found 21 spikes of frequency 2.665
# simulation result:
# ANN result: tensor([[ 2.1039, 10.3199,  2.2474, 10.3672,  7.8552,  8.9156,  5.4738,  4.0194,
#          22.4052, 13.7504]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.7231909220001853 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 25.779772731000094 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.41131907299996 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.11778276800009735 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 27 spikes of frequency 2.230769230769231
# for 2 found 13 spikes of frequency 4.766666666666667
# for 3 found 28 spikes of frequency 2.1851851851851856
# for 4 found 26 spikes of frequency 2.236
# for 5 found 28 spikes of frequency 2.2111111111111112
# for 6 found 3 spikes of frequency 3.3000000000000007
# for 7 found 22 spikes of frequency 2.361904761904762
# for 8 found 28 spikes of frequency 2.285185185185185
# for 9 found 27 spikes of frequency 2.1769230769230767
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
