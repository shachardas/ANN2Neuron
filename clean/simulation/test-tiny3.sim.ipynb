# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.3):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale=1):
        scale_wrong = max(sum(output[0])/len(output[0]), 5) * scale
        scale_true = scale_wrong * 3
        tempLabels = torch.ones_like(output)* -1 * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 50, bias=False)
        self.fc4 = BinarizeLinear(50, 10, bias=False)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-tiny3.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -5.,  -2.,   2., -10.,  -2.,  10.,  -5.,  -3.,  -4.,  -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.408305382 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.046254177000000674 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 2 spikes of frequency 4.899999999999999
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 7 spikes of frequency 2.3666666666666667
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 18.,  -9.,  -1.,  -8.,  -6.,   0.,  -9.,  -2.,  -4., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3517850279999948 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.05382930499999361 seconds
# creating stimulation
# starting to record
# for 0 found 7 spikes of frequency 2.283333333333333
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-2., -8., -2., -6., 13.,  2., -7., -5., -7., -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3440718279999828 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.06182167299999719 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 7 spikes of frequency 2.3333333333333335
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -7.,  10.,   4.,  -2.,  -4.,  -7.,  -3.,  -3.,  -3., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.273451184999999 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.06621548200001826 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 6 spikes of frequency 2.34
# for 2 found 1 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[  1.,  -3.,   0., -15.,   0.,  -4.,  -4.,  -7.,  -3.,   6.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.25101375899998857 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.029053575999967052 seconds
# creating stimulation
# starting to record
# for 0 found 1 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 6 spikes of frequency 2.46
# simulation result:
# ANN result: tensor([[ -2., -10.,  10.,  -8.,  -6.,  -7.,  -1.,  -5.,  -3.,  -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.37742990200001714 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.07489739200002532 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 6 spikes of frequency 2.32
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -2.,  -8.,  -4.,  13.,  -5.,  -5.,  -6.,  -9.,  -2., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.32875011999999515 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.09535838100003957 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 7 spikes of frequency 2.3833333333333333
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -5.,  -7.,  -3.,  -1.,   2.,  -5.,  10.,  -8.,  -1., -11.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.3544563420000486 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.06495028299991645 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 6 spikes of frequency 2.3
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 2., -8., -9., -9., -2., -3., -4.,  9., -6., -1.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.2787792710000758 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.10751605999996627 seconds
# creating stimulation
# starting to record
# for 0 found 3 spikes of frequency 2.9499999999999993
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 6 spikes of frequency 2.3400000000000003
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-2., -4., -7., -5., -6., -1., -1., -6., 12., -7.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.2769093269999985 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.09463772499998413 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 5 spikes of frequency 2.3249999999999997
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
