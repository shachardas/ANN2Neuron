# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.1):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels):
        tempOut = torch.where(output>-1,(output+2),torch.zeros_like(output))

        for i in range(labels.size(0)):
            tempOut[i,labels[i]] = 0

        return self.p    * torch.mean(tempOut) \
            + (1-self.p) * self.cost(output,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.max(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.min(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

"""def Binarize(tensor, include_zero = True):
        if include_zero:
            return ((tensor+0.5).sign()+(tensor-0.5).sign())/2
        else:
            return tensor.sign()"""

class PositiveBinarizeLinear(nn.Linear):

        def __init__(self, *kargs, **kwargs):
            super(PositiveBinarizeLinear, self).__init__(*kargs, **kwargs)
    
        def forward(self, input):
            
            if input.size(1) != 784:
                input.data=Binarize(input.data)
                input.data = input.data.add(1).div(2)
            #zero = torch.zeros_like(input.data)
            #input.data = torch.where(input.data > 0, input.data, zero)
            input.data=Binarize(input.data)
            if not hasattr(self.weight,'org'):
                self.weight.org=self.weight.data.clone()
            self.weight.data=Binarize(self.weight.org)
            out = nn.functional.linear(input, self.weight)
            if not self.bias is None:
                self.bias.org=self.bias.data.clone()
                out += self.bias.view(1, -1).expand_as(out)

            return out

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

# simplified batchnorm with no mean normalization and separate learnable parameters for positive and negatives
class myBatchNorm1d(nn.BatchNorm1d):

    def __init__(self, size):
        super(myBatchNorm1d, self).__init__(size)
        self.eps = 1e-5
        self.l1 = nn.Parameter(torch.ones(size))
        self.l2 = nn.Parameter(torch.ones(size))
        self.running_var = torch.ones(size)
        self.momentum = 0.1

    def forward(self, input):
        device = input.get_device()
        if input.size()[0] != 1:
            self.running_var = (1-self.momentum) * self.running_var + self.momentum * torch.var(input, keepdim=True, dim=0)
            bottom = torch.sqrt(torch.var(input, keepdim=True, dim=0) + self.eps)
        else:
            bottom = torch.sqrt(self.running_var + self.eps)

        top = input * torch.sigmoid(10 * input) * self.l1 + input * torch.sigmoid(-10 * input) * self.l2
        
        out = top/bottom

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.infl_ratio=3
        self.fc1 = BinarizeLinear(784, 1024*self.infl_ratio, bias=False)
        self.htanh1 = nn.Hardtanh()
        self.bn1 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc2 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh2 = nn.Hardtanh()
        self.bn2 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc3 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh3 = nn.Hardtanh()
        self.bn3 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc4 = BinarizeLinear(1024*self.infl_ratio, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()
        self.drop=nn.Dropout(0.5)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.htanh1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.htanh2(x)
        x = self.fc3(x) 
        x = self.drop(x)
        x = self.bn3(x)
        x = self.htanh3(x)
        x = self.fc4(x)
        return x#self.logsoftmax(x)


model = Net()
model.load_state_dict(torch.load("trained_models/DNN_customloss_allBinary.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[-402., -200., -196., -134., -496.,   50., -344., -490., -168., -612.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# /home/shachar/nestDocker/ANN2Neuron/clean/simulation/modules/dishNetwork.py:19: UserWarning:To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# this took 5.12703989 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 47.284651755000006 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 39.006926198 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.16285305399999572 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 10 spikes of frequency 2.1999999999999997
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 224., -322., -102., -198., -444., -174., -250., -224., -258., -266.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.148357161999996 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 34.975628712 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.24982034300001 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.16731661400001485 seconds
# creating stimulation
# starting to record
# for 0 found 19 spikes of frequency 2.1055555555555556
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-342., -320., -136., -278.,  224.,  -90., -188., -310., -160., -252.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.024906844999975 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.976863863999995 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.614624106999997 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1258363480000071 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 26 spikes of frequency 2.1279999999999997
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-398.,  306., -224., -160., -328., -284., -126., -276.,  -84., -180.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.078712144000008 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.49663504900002 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.323084935999987 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.13410958200000778 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 26 spikes of frequency 2.2
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-548., -310., -498., -280., -142., -284., -542., -264., -358.,  130.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.672170876999985 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.922405974999947 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 34.729306640000004 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12037871299992275 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 6 spikes of frequency 2.1
# simulation result:
# ANN result: tensor([[-419., -425.,  183., -207., -317., -453., -459., -351., -351., -449.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.000618304 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 26.883114862999946 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.440113067000084 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.14353672499998993 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 25 spikes of frequency 2.1625
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-496., -212., -406.,  240., -394., -310., -472., -394., -310., -232.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.116226510000047 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 23.82624492299999 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.152810421000027 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.11758848700003455 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 28 spikes of frequency 2.1555555555555554
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-306., -258.,  -94., -156., -134., -156.,  176., -274., -162., -234.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.5190661369999816 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 25.38229577200002 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.970730427000035 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12006740200001786 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 16 spikes of frequency 2.1
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-353., -257., -543., -225., -195., -277., -613.,  261., -335.,  -33.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.895208399000012 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.846657061999963 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 24.854796393000015 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.14097435999997288 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 20 spikes of frequency 2.1210526315789475
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-262., -206., -292., -284., -256., -406., -298., -322.,  176., -170.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.774616556999945 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 25.587512393999987 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 25.433922725000002 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.16059635100009473 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 13 spikes of frequency 2.1166666666666667
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
