# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.1):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_true=10, scale_wrong=-10):
        # scale_wrong = max(sum(output[0])/len(output[0]), 2) * scale
        # scale_true = scale_wrong * 10
        tempOut = torch.where(output>0,output*scale_wrong,torch.zeros_like(output))
        tempLabels = torch.ones_like(output) * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            #tempLabels[i,j] = scale_true 
            tempLabels[i,j] = torch.max(torch.abs(torch.mean(output[i])), torch.abs(output[i,j]))*scale_true
        #output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(tempOut, tempLabels) \
            + (1-self.p) * self.cost(output,labels)


criterion = nn.CrossEntropyLoss()
#criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.max(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.min(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

"""def Binarize(tensor, include_zero = True):
        if include_zero:
            return ((tensor+0.5).sign()+(tensor-0.5).sign())/2
        else:
            return tensor.sign()"""

class PositiveBinarizeLinear(nn.Linear):

        def __init__(self, *kargs, **kwargs):
            super(PositiveBinarizeLinear, self).__init__(*kargs, **kwargs)
    
        def forward(self, input):
            
            if input.size(1) != 784:
                input.data=Binarize(input.data)
                input.data = input.data.add(1).div(2)
            #zero = torch.zeros_like(input.data)
            #input.data = torch.where(input.data > 0, input.data, zero)
            input.data=Binarize(input.data)
            if not hasattr(self.weight,'org'):
                self.weight.org=self.weight.data.clone()
            self.weight.data=Binarize(self.weight.org)
            out = nn.functional.linear(input, self.weight)
            if not self.bias is None:
                self.bias.org=self.bias.data.clone()
                out += self.bias.view(1, -1).expand_as(out)

            return out

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

# simplified batchnorm with no mean normalization and separate learnable parameters for positive and negatives
class myBatchNorm1d(nn.BatchNorm1d):

    def __init__(self, size):
        super(myBatchNorm1d, self).__init__(size)
        self.eps = 1e-5
        self.l1 = nn.Parameter(torch.ones(size))
        self.l2 = nn.Parameter(torch.ones(size))
        self.running_var = torch.ones(size)
        self.momentum = 0.1

    def forward(self, input):
        device = input.get_device()
        if input.size()[0] != 1:
            self.running_var = (1-self.momentum) * self.running_var + self.momentum * torch.var(input, keepdim=True, dim=0)
            bottom = torch.sqrt(torch.var(input, keepdim=True, dim=0) + self.eps)
        else:
            bottom = torch.sqrt(self.running_var + self.eps)

        top = input * torch.sigmoid(10 * input) * self.l1 + input * torch.sigmoid(-10 * input) * self.l2
        
        out = top/bottom

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.infl_ratio=3
        self.fc1 = BinarizeLinear(784, 1024*self.infl_ratio, bias=False)
        self.htanh1 = nn.Hardtanh()
        self.bn1 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc2 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh2 = nn.Hardtanh()
        self.bn2 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc3 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh3 = nn.Hardtanh()
        self.bn3 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc4 = nn.Linear(1024*self.infl_ratio, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()
        self.drop=nn.Dropout(0.5)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.htanh1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.htanh2(x)
        x = self.fc3(x) 
        x = self.drop(x)
        x = self.bn3(x)
        x = self.htanh3(x)
        x = self.fc4(x)
        return x#self.logsoftmax(x)


model = Net()
model.load_state_dict(torch.load("trained_models/DNN_custom_bn.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[ -3.5103,  -6.1153,  -5.3676,   8.4918, -10.6479,  36.8357,  -4.4545,
#           -9.5359,   9.5448, -15.7675]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# /home/shachar/nestDocker/ANN2Neuron/clean/simulation/modules/dishNetwork.py:19: UserWarning:To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# this took 4.991995666000001 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 34.294773096 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 33.994948731 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.18055649600000834 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 11 spikes of frequency 5.15
# for 3 found 22 spikes of frequency 2.3190476190476192
# for 4 found 0 spikes
# for 5 found 25 spikes of frequency 2.1625
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 24 spikes of frequency 2.286956521739131
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ 42.2054,  -6.3390,  -1.2013,  -7.7081, -12.5308,  -2.2437,   1.1654,
#           -5.6507,  -2.2249,  -1.7388]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.9221025939999947 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.64332534800002 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.66010370700002 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1435251839999978 seconds
# creating stimulation
# starting to record
# for 0 found 26 spikes of frequency 2.14
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 15 spikes of frequency 3.935714285714286
# for 6 found 1 spikes
# for 7 found 3 spikes of frequency 24.2
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -9.9840, -10.7583,  -4.2907, -11.2864,  39.1701,   0.0679,  -6.8078,
#            8.8653,  -3.2518,  -1.1826]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.159701409000036 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.02146442999998 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 32.089592502000016 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.15630314500003806 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 26 spikes of frequency 2.156
# for 5 found 23 spikes of frequency 2.3636363636363638
# for 6 found 0 spikes
# for 7 found 22 spikes of frequency 2.295238095238095
# for 8 found 5 spikes of frequency 12.1
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-12.6967,  33.0618, -10.9044,   0.7328,  -9.9288, -14.3120,  -4.3140,
#            9.3727,   7.6721,   4.1231]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.270698181 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.805463677000034 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 26.756809655999973 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1283975319999513 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 25 spikes of frequency 2.1958333333333333
# for 2 found 0 spikes
# for 3 found 25 spikes of frequency 2.3875000000000006
# for 4 found 0 spikes
# for 5 found 1 spikes
# for 6 found 0 spikes
# for 7 found 15 spikes of frequency 2.3285714285714283
# for 8 found 24 spikes of frequency 2.3086956521739133
# for 9 found 16 spikes of frequency 2.6866666666666665
# simulation result:
# ANN result: tensor([[ -5.4149, -10.8985, -21.8648,   9.4330,   4.9783,  -8.3699, -26.4625,
#            8.8406,   1.8437,  33.7014]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.165177223000001 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.131333074999986 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.855547960999957 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.10540364500002397 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 23 spikes of frequency 2.268181818181818
# for 4 found 20 spikes of frequency 2.405263157894737
# for 5 found 1 spikes
# for 6 found 0 spikes
# for 7 found 25 spikes of frequency 2.170833333333333
# for 8 found 15 spikes of frequency 2.721428571428571
# for 9 found 26 spikes of frequency 2.224
# simulation result:
# ANN result: tensor([[  3.3901,  -5.5328,  38.0605,   6.6474,  -8.3665, -24.6383,  -8.6817,
#           12.9489,  -1.5132, -11.6563]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.280724598000006 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.141816108999933 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.36284007400002 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.14392563399997016 seconds
# creating stimulation
# starting to record
# for 0 found 21 spikes of frequency 2.4050000000000002
# for 1 found 0 spikes
# for 2 found 27 spikes of frequency 2.2346153846153847
# for 3 found 23 spikes of frequency 2.259090909090909
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 26 spikes of frequency 2.24
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-11.4616,  -0.5270,  -1.9324,  34.2109,  -5.4925,  -5.1021, -26.2436,
#           -2.6500,   4.8369,  -0.8798]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.211439380999991 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 26.545238911999945 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.625179516999992 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.22641379700007747 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 19 spikes of frequency 2.961111111111111
# for 2 found 12 spikes of frequency 4.890909090909091
# for 3 found 27 spikes of frequency 2.292307692307692
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 10 spikes of frequency 5.644444444444445
# for 8 found 22 spikes of frequency 2.3714285714285714
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[  6.5549, -12.8519,  -6.5427,  -7.0888,  -1.9644,  10.9355,  40.3447,
#          -17.9343,   6.0374,  -9.5617]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.7656519129999424 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 26.407269919999976 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.616832684999963 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.09916139599999951 seconds
# creating stimulation
# starting to record
# for 0 found 8 spikes of frequency 2.5285714285714285
# for 1 found 0 spikes
# for 2 found 5 spikes of frequency 2.6750000000000007
# for 3 found 0 spikes
# for 4 found 4 spikes of frequency 16.999999999999996
# for 5 found 23 spikes of frequency 2.3045454545454547
# for 6 found 26 spikes of frequency 2.232
# for 7 found 0 spikes
# for 8 found 22 spikes of frequency 2.3523809523809525
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[  3.9091,   0.5797, -10.0232,  -2.6738,  -1.6049, -14.7580, -27.5723,
#           40.9488,  -4.0676,  12.6415]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.024712566000062 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.595305147999966 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.70646952900006 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1607263939999939 seconds
# creating stimulation
# starting to record
# for 0 found 19 spikes of frequency 2.6111111111111116
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 9 spikes of frequency 6.25
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 26 spikes of frequency 2.136
# for 8 found 0 spikes
# for 9 found 26 spikes of frequency 2.224
# simulation result:
# ANN result: tensor([[ -1.3892,   1.8729,   1.1365,   0.9085,  -8.2088,  -9.7154, -20.5698,
#           -6.3802,  29.6955,   2.9836]], grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.071419841000079 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 32.57384563100004 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.93881145599994 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.16009801600011997 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 19 spikes of frequency 2.6277777777777778
# for 2 found 17 spikes of frequency 2.9562500000000003
# for 3 found 23 spikes of frequency 2.490909090909091
# for 4 found 0 spikes
# for 5 found 2 spikes of frequency 52.199999999999996
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 26 spikes of frequency 2.2359999999999998
# for 9 found 10 spikes of frequency 3.677777777777779
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-070c79eef60f> in <module>
# ----> 1 parse, sum = sim.testSim(res, model_act,4,1,4)
#       2 pprint(parse)
#       3 print("sum:",sum)
#
# TypeError: testSim() missing 1 required positional argument: 'targetInNextLayer'
