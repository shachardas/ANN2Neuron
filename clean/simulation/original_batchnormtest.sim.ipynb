# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.5):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale_true=10, scale_wrong=-10):
        # scale_wrong = max(sum(output[0])/len(output[0]), 2) * scale
        # scale_true = scale_wrong * 10
        tempOut = torch.where(output>0,output*scale_wrong,torch.zeros_like(output))
        tempLabels = torch.ones_like(output) * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            #tempLabels[i,j] = scale_true 
            tempLabels[i,j] = torch.max(torch.abs(torch.mean(output[i])), torch.abs(output[i,j]))*scale_true
        #output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(tempOut, tempLabels) \
            + (1-self.p) * self.cost(output,labels)


criterion = nn.CrossEntropyLoss()
#criterion = customLoss()

def Binarize(tensor, include_zero = False, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.max(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.min(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

"""def Binarize(tensor, include_zero = True):
        if include_zero:
            return ((tensor+0.5).sign()+(tensor-0.5).sign())/2
        else:
            return tensor.sign()"""

class PositiveBinarizeLinear(nn.Linear):

        def __init__(self, *kargs, **kwargs):
            super(PositiveBinarizeLinear, self).__init__(*kargs, **kwargs)
    
        def forward(self, input):
            
            if input.size(1) != 784:
                input.data=Binarize(input.data)
                input.data = input.data.add(1).div(2)
            #zero = torch.zeros_like(input.data)
            #input.data = torch.where(input.data > 0, input.data, zero)
            input.data=Binarize(input.data)
            if not hasattr(self.weight,'org'):
                self.weight.org=self.weight.data.clone()
            self.weight.data=Binarize(self.weight.org)
            out = nn.functional.linear(input, self.weight)
            if not self.bias is None:
                self.bias.org=self.bias.data.clone()
                out += self.bias.view(1, -1).expand_as(out)

            return out

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

# simplified batchnorm with no mean normalization or learnable parameters
class myBatchNorm1d(nn.BatchNorm1d):

    def __init__(self, *kargs, **kwargs):
        super(myBatchNorm1d, self).__init__(*kargs, **kwargs)
        self.eps = 1e-5

    def forward(self, input):

        top = input
        bottom = torch.sqrt(torch.var(input) + self.eps)

        out = top/bottom

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.infl_ratio=3
        self.fc1 = BinarizeLinear(784, 1024*self.infl_ratio, bias=False)
        self.htanh1 = nn.Hardtanh()
        self.bn1 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc2 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh2 = nn.Hardtanh()
        self.bn2 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc3 = BinarizeLinear(1024*self.infl_ratio, 1024*self.infl_ratio, bias=False)
        self.htanh3 = nn.Hardtanh()
        self.bn3 = myBatchNorm1d(1024*self.infl_ratio)
        self.fc4 = nn.Linear(1024*self.infl_ratio, 10, bias=False)
        self.logsoftmax=nn.LogSoftmax()
        self.drop=nn.Dropout(0.5)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.htanh1(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.htanh2(x)
        x = self.fc3(x) 
        x = self.drop(x)
        x = self.bn3(x)
        x = self.htanh3(x)
        x = self.fc4(x)
        return self.logsoftmax(x)


model = Net()
model.load_state_dict(torch.load("trained_models/original_batchnormtest.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# <ipython-input-1-b2f894318577>:137: UserWarning:Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# ANN result: tensor([[-1.6814e+01, -1.4225e+01, -1.5611e+01, -1.4276e+01, -1.5919e+01,
#          -8.7853e-05, -1.2157e+01, -2.1412e+01, -9.4224e+00, -1.7527e+01]],
#        grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# /home/shachar/nestDocker/ANN2Neuron/clean/simulation/modules/dishNetwork.py:19: UserWarning:To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# this took 6.165333419 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 40.79388826099999 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 34.417152253 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1786083829999967 seconds
# creating stimulation
# starting to record
# for 0 found 2 spikes of frequency 2.700000000000003
# for 1 found 26 spikes of frequency 2.2560000000000002
# for 2 found 25 spikes of frequency 2.2916666666666665
# for 3 found 26 spikes of frequency 2.196
# for 4 found 24 spikes of frequency 2.3782608695652168
# for 5 found 28 spikes of frequency 2.196296296296296
# for 6 found 26 spikes of frequency 2.32
# for 7 found 18 spikes of frequency 3.0588235294117645
# for 8 found 28 spikes of frequency 2.2185185185185183
# for 9 found 6 spikes of frequency 2.8200000000000003
# simulation result:
# ANN result: tensor([[  0.0000, -38.5229, -18.8178, -19.8192, -33.4789, -17.1451, -17.5937,
#          -28.8870, -21.9232, -21.0175]], grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.8767025639999986 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.07843410700002 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.591861856999998 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.13027706200000466 seconds
# creating stimulation
# starting to record
# for 0 found 27 spikes of frequency 2.1884615384615387
# for 1 found 0 spikes
# for 2 found 16 spikes of frequency 2.7400000000000007
# for 3 found 1 spikes
# for 4 found 0 spikes
# for 5 found 22 spikes of frequency 2.6285714285714286
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-1.6078e+01, -1.3243e+01, -1.2768e+01, -1.8723e+01, -9.4290e-05,
#          -1.0905e+01, -1.0025e+01, -1.5438e+01, -1.0705e+01, -1.2388e+01]],
#        grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.169752743999993 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.463792026999954 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 30.758172375000015 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.11908645199997636 seconds
# creating stimulation
# starting to record
# for 0 found 9 spikes of frequency 5.525
# for 1 found 26 spikes of frequency 2.3760000000000003
# for 2 found 24 spikes of frequency 2.4130434782608696
# for 3 found 10 spikes of frequency 6.2
# for 4 found 28 spikes of frequency 2.1370370370370373
# for 5 found 28 spikes of frequency 2.1814814814814816
# for 6 found 27 spikes of frequency 2.15
# for 7 found 26 spikes of frequency 2.3040000000000003
# for 8 found 27 spikes of frequency 2.2
# for 9 found 26 spikes of frequency 2.248
# simulation result:
# ANN result: tensor([[-3.4317e+01, -1.6689e-06, -2.0251e+01, -1.3343e+01, -2.6229e+01,
#          -2.6330e+01, -2.3695e+01, -2.1374e+01, -1.5980e+01, -1.9912e+01]],
#        grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.408217394000019 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.79099747099997 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.267927728000018 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12892540999996527 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 27 spikes of frequency 2.2115384615384612
# for 2 found 11 spikes of frequency 5.130000000000001
# for 3 found 25 spikes of frequency 2.2583333333333333
# for 4 found 0 spikes
# for 5 found 9 spikes of frequency 6.624999999999999
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 14 spikes of frequency 3.9461538461538463
# for 9 found 2 spikes of frequency 2.9999999999999982
# simulation result:
# ANN result: tensor([[-28.1791, -31.6999, -31.9146, -18.4940, -23.0359, -20.8246, -31.5798,
#          -27.5511, -22.5269,   0.0000]], grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.000712928999974 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.711268023999992 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.77557788599995 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1701683819999289 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 5 spikes of frequency 11.85
# for 4 found 7 spikes of frequency 8.65
# for 5 found 9 spikes of frequency 6.587500000000001
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 0 spikes
# for 9 found 27 spikes of frequency 2.1461538461538465
# simulation result:
# ANN result: tensor([[-32.3706, -48.7496,   0.0000, -23.1266, -31.8695, -51.3335, -45.7979,
#          -23.4160, -36.8323, -37.5888]], grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.860164597999983 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.89429814899995 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.49424945599992 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.16058135799994488 seconds
# creating stimulation
# starting to record
# for 0 found 8 spikes of frequency 2.557142857142857
# for 1 found 0 spikes
# for 2 found 28 spikes of frequency 2.244444444444445
# for 3 found 26 spikes of frequency 2.2
# for 4 found 1 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 23 spikes of frequency 2.2727272727272725
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-27.9397, -27.0945, -17.4231,   0.0000, -33.2322, -22.7010, -35.9308,
#          -18.7196, -23.2084, -19.1156]], grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.293755767999983 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.009370376999982 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 28.65126899200004 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.1362019750000627 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 1 spikes
# for 2 found 2 spikes of frequency 2.3000000000000007
# for 3 found 27 spikes of frequency 2.134615384615384
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 1 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-1.3107e+01, -1.3396e+01, -1.1645e+01, -1.5769e+01, -9.2295e+00,
#          -8.6309e+00, -3.4112e-04, -2.4618e+01, -9.8668e+00, -1.5712e+01]],
#        grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 3.913992106999899 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 27.458253252000077 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 29.519752280000034 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.12660808800001178 seconds
# creating stimulation
# starting to record
# for 0 found 19 spikes of frequency 2.561111111111111
# for 1 found 25 spikes of frequency 2.379166666666667
# for 2 found 26 spikes of frequency 2.2640000000000002
# for 3 found 26 spikes of frequency 2.4360000000000004
# for 4 found 28 spikes of frequency 2.2703703703703706
# for 5 found 28 spikes of frequency 2.1518518518518523
# for 6 found 28 spikes of frequency 2.1555555555555554
# for 7 found 0 spikes
# for 8 found 28 spikes of frequency 2.2222222222222223
# for 9 found 25 spikes of frequency 2.341666666666667
# simulation result:
# ANN result: tensor([[-1.1283e+01, -1.9863e+01, -1.8025e+01, -1.0493e+01, -1.2898e+01,
#          -1.4548e+01, -2.3139e+01, -1.0687e-02, -1.3862e+01, -4.5482e+00]],
#        grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.210548347000213 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 33.945921563999946 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 34.151685170000064 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.18756074300017644 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 1 spikes
# for 6 found 0 spikes
# for 7 found 27 spikes of frequency 2.184615384615385
# for 8 found 0 spikes
# for 9 found 26 spikes of frequency 2.212
# simulation result:
# ANN result: tensor([[-30.8193, -30.9211, -36.2431, -22.4526, -29.9262, -23.8527, -26.0189,
#          -43.0646,   0.0000, -22.2983]], grad_fn=<LogSoftmaxBackward0>)
# simulating ANN of layers [784, 6144, 6144, 6144, 10]
# creating 784 nodes
# creating 6144 nodes
# connecting 784 neurons to 6144 neurons
# this took 4.56745881300003 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.44485084200005 seconds
# creating 6144 nodes
# connecting 6144 neurons to 6144 neurons
# this took 31.04968281100014 seconds
# creating 10 nodes
# connecting 6144 neurons to 10 neurons
# this took 0.13098721799997293 seconds
# creating stimulation
# starting to record
# for 0 found 4 spikes of frequency 2.933333333333335
# for 1 found 25 spikes of frequency 2.341666666666667
# for 2 found 16 spikes of frequency 3.6599999999999997
# for 3 found 27 spikes of frequency 2.1384615384615384
# for 4 found 9 spikes of frequency 2.5000000000000004
# for 5 found 27 spikes of frequency 2.134615384615384
# for 6 found 12 spikes of frequency 2.254545454545455
# for 7 found 1 spikes
# for 8 found 27 spikes of frequency 2.1538461538461537
# for 9 found 26 spikes of frequency 2.16
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-070c79eef60f> in <module>
# ----> 1 parse, sum = sim.testSim(res, model_act,4,1,4)
#       2 pprint(parse)
#       3 print("sum:",sum)
#
# TypeError: testSim() missing 1 required positional argument: 'targetInNextLayer'
