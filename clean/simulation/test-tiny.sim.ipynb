# %%
import torch
import modules.model2sim as sim

import torch
import torch.nn as nn
import numpy as np

class customLoss(nn.Module):
    def __init__(self, p=0.3):
        super().__init__()
        self.p = p
        self.cost = nn.CrossEntropyLoss()
        self.cost2 = nn.L1Loss()

    def forward(self, output, labels, scale=1):
        scale_wrong = max(sum(output[0])/len(output[0]), 10) * scale
        scale_true = scale_wrong * 3
        tempLabels = torch.ones_like(output)* -1 * scale_wrong
        for i in range(labels.size(0)):
            j = labels[i]
            tempLabels[i,j] = scale_true 
        output_softmax = nn.LogSoftmax()(output)
        return self.p    * self.cost2(output, tempLabels) \
            + (1-self.p) * self.cost(output_softmax,labels)


#criterion = nn.CrossEntropyLoss()
criterion = customLoss()

def Binarize(tensor, include_zero = True, minSig=3):
    if include_zero:
        P_std = 0.25
        up_lim = torch.min(0 + P_std*tensor.std(), torch.ones_like(tensor)*minSig)
        down_lim = torch.max(0 - P_std*tensor.std(), -1*torch.ones_like(tensor)*minSig)
        up_v = (tensor>up_lim).float()
        down_v = (tensor<down_lim).float().mul(-1)
        return (up_v + down_v)
    else:
        return tensor.sign()

class BinarizeLinear(nn.Linear):

    def __init__(self, *kargs, **kwargs):
        super(BinarizeLinear, self).__init__(*kargs, **kwargs)

    def forward(self, input):

        if input.size(1) != 784:
            input.data=Binarize(input.data)
        if not hasattr(self.weight,'org'):
            self.weight.org=self.weight.data.clone()
        self.weight.data=Binarize(self.weight.org)
        out = nn.functional.linear(input, self.weight)
        if not self.bias is None:
            self.bias.org=self.bias.data.clone()
            out += self.bias.view(1, -1).expand_as(out)

        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = BinarizeLinear(784, 50, bias=False)
        self.fc4 = BinarizeLinear(50, 10, bias=False)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc4(x)
        return x
"""
    def test(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x"""



model = Net()
model.load_state_dict(torch.load("trained_models/test-tiny.pt",map_location=torch.device('cpu')))
model.eval()
res, model_act = sim.testMNIST(model)
# Out:
# ANN result: tensor([[-13.,   1.,  -5., -10.,  -7.,   7., -13.,  -7.,  -5., -19.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.19771121299999983 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.009814737000000129 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 3 spikes of frequency 6.499999999999999
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 7 spikes of frequency 2.4999999999999996
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# /home/shachar/nestDocker/ANN2Neuron/clean/simulation/modules/dishNetwork.py:19: UserWarning:To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ANN result: tensor([[ 11.,  -9., -11., -12., -11., -11., -12.,  -7.,  -9., -10.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.16426356300000045 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0021248590000002565 seconds
# creating stimulation
# starting to record
# for 0 found 8 spikes of frequency 2.3000000000000003
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-13., -11.,  -8.,  -8.,   6.,  -7., -11., -11.,  -9., -12.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.1604873659999999 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0013055430000008528 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 7 spikes of frequency 2.566666666666667
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-13.,   8., -12.,  -8., -12.,  -9.,  -8., -10.,  -8., -12.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.12970381599999925 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.02931855799999994 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 6 spikes of frequency 2.42
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -7.,  -5., -13., -17., -10.,  -9., -14.,  -8.,  -9.,   5.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.19214168699999945 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.029858506000000062 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 3 spikes of frequency 2.5500000000000007
# simulation result:
# ANN result: tensor([[-11., -13.,  -3.,  -6.,  -8.,  -8.,  -8.,  -7.,  -8., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.16333527699999983 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0015440430000008831 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-10.,  -8., -12.,   9., -10.,  -7., -10., -11., -10., -13.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15968076499999917 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0014591700000003982 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 6 spikes of frequency 2.4
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -7.,  -6.,  -7.,  -8.,  -6., -10.,   6., -14., -10., -14.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15898250299999894 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0012626840000002915 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 6 spikes of frequency 2.5599999999999996
# for 7 found 0 spikes
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[ -8.,  -8., -17., -10.,  -8., -11., -12.,   5.,  -7.,  -5.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.160192275 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0016160549999995055 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 8 spikes of frequency 3.0714285714285707
# for 8 found 0 spikes
# for 9 found 0 spikes
# simulation result:
# ANN result: tensor([[-11.,  -7., -12.,  -6., -11.,  -6.,  -8., -15.,   2.,  -8.]],
#        grad_fn=<MmBackward0>)
# simulating ANN of layers [784, 100, 10]
# creating 784 nodes
# creating 100 nodes
# connecting 784 neurons to 100 neurons
# this took 0.15974142800000024 seconds
# creating 10 nodes
# connecting 100 neurons to 10 neurons
# this took 0.0009897320000007426 seconds
# creating stimulation
# starting to record
# for 0 found 0 spikes
# for 1 found 0 spikes
# for 2 found 0 spikes
# for 3 found 0 spikes
# for 4 found 0 spikes
# for 5 found 0 spikes
# for 6 found 0 spikes
# for 7 found 0 spikes
# for 8 found 2 spikes of frequency 2.599999999999998
# for 9 found 0 spikes
# simulation result:

# %%
parse, sum = sim.testSim(res, model_act,4,1,4)
pprint(parse)
print("sum:",sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-070c79eef60f> in <module>
# ----> 1 parse, sum = sim.testSim(res, model_act,4,1,4)
#       2 pprint(parse)
#       3 print("sum:",sum)
#
# TypeError: testSim() missing 1 required positional argument: 'targetInNextLayer'
